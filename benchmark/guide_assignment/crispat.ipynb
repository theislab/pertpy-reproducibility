# %%
import crispat

# %%
# Not working
crispat.ga_poisson_gauss(
    "../data/sim_dat.h5ad",
    "sim_dat_crispat_ga_umi",
    start_gRNA=1,
)
# Out:
# Guide assignment with Poisson-Gaussian mixture model as in Replogle et al.
# The output directory sim_dat_crispat_ga_umi was created
# Load gRNA counts
# Fit Poisson-Gaussian Mixture Model for each gRNA:
#   0%|          | 0/3 [00:00<?, ?it/s]/g/huber/users/peidli/miniconda3/envs/crispat_env/lib/python3.11/site-packages/pyro/poutine/trace_struct.py:280: UserWarning: Encountered NaN: log_prob_sum at site 'obs'
#   warn_if_nan(
# /g/huber/users/peidli/miniconda3/envs/crispat_env/lib/python3.11/site-packages/pyro/infer/traceenum_elbo.py:412: UserWarning: Encountered NaN: loss
#   warn_if_nan(loss, "loss")
# /g/huber/users/peidli/miniconda3/envs/crispat_env/lib/python3.11/site-packages/pyro/poutine/trace_struct.py:280: UserWarning: Encountered NaN: log_prob_sum at site 'obs'
#   warn_if_nan(
# /g/huber/users/peidli/miniconda3/envs/crispat_env/lib/python3.11/site-packages/pyro/infer/traceenum_elbo.py:412: UserWarning: Encountered NaN: loss
#   warn_if_nan(loss, "loss")
# ...
