# %% [markdown]
# # Lang Augur

# %%
import warnings

warnings.filterwarnings("ignore")

# %%
from pathlib import Path
import sys

sys.path.insert(1, str(Path().cwd().parent))
import common_config

# %%
common_config.figure_journal_basic()

# %%
import pertpy as pt
import scanpy as sc
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# ryp2 is not installed. Install with pip install rpy2 to run tools with R support.

# %%
adata = sc.read_h5ad("230114_hPCLS_perturbation.h5ad")

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 63581 × 17343
#     obs: 'condition', 'modality', 'patient', 'treatment', 'identifier', 'n_counts', 'n_genes', 'percent_mito', 'QC_group', 'doublet_scores', 'size_factors', 'leiden_1', 'leiden_2', 'cell_type', 'cell_type_group', 'sample'
#     var: 'n_cells', 'n_counts', 'means', 'dispersions', 'dispersions_norm', 'highly_variable', 'highly_variable_nbatches', 'highly_variable_intersection'
#     uns: 'QC_group_colors', 'cell_type_colors', 'cell_type_group_colors', 'condition_colors', 'dendrogram_cell_type', 'hvg', 'identifier_colors', 'leiden', 'leiden_1_colors', 'leiden_2_colors', 'modality_colors', 'name_colors', 'neighbors', 'patient_colors', 'pca', 'rank_genes_groups', 'sample_colors', 'timepoint_colors', 'treatment_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     layers: 'counts', 'unsouped_counts'
#     obsp: 'connectivities', 'distances'

# %%
ag_rfc = pt.tl.Augur("random_forest_classifier")

# %%
adata = adata[
    adata.obs.cell_type.isin(
        [
            "Aberrant Basaloid",
            "Myofibroblasts",
            "ectopic EC",
            "Profibrotic Macrophages",
            "Pericytes",
        ]
    )
]

# %%
adata1 = adata[adata.obs.treatment.isin(["FC", "FC+Nintedanib"])].copy()
adata2 = adata[adata.obs.treatment.isin(["FC", "FC+CMP4"])].copy()

# %%
adata1.obs["label"] = adata1.obs["treatment"]

# %%
adata2.obs["label"] = adata2.obs["treatment"]

# %%
loaded_data1 = ag_rfc.load(adata1)
loaded_data2 = ag_rfc.load(adata2)

# %%
loaded_data1.var["name"] = loaded_data1.var_names

# %%
loaded_data2.var["name"] = loaded_data2.var_names

# %%
nintedanib_adata, nintedanib_results = ag_rfc.predict(
    loaded_data1,
    n_subsamples=100,
    subsample_size=20,
    n_threads=32,
    select_variance_features=True,
)

nintedanib_results["summary_metrics"]
# Out:
# Set smaller span value in the case of a `segmentation fault` error.
# Set larger span in case of svddc or other near singularities error.
# ryp2 is not installed. Install with pip install rpy2 to run tools with R
# support.
# ryp2 is not installed. Install with pip install rpy2 to run tools with R
# support.
# ryp2 is not installed. Install with pip install rpy2 to run tools with R
# support.
# ryp2 is not installed. Install with pip install rpy2 to run tools with R
# support.
# ryp2 is not installed. Install with pip install rpy2 to run tools with R
# support.
# ryp2 is not installed. Install with pip install rpy2 to run tools with R
# support.
# ryp2 is not installed. Install with pip install rpy2 to run tools with R
# support.
# ryp2 is not installed. Install with pip install rpy2 to run tools with R
# support.
# ryp2 is not installed. Install with pip install rpy2 to run tools with R
# support.
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# ryp2 is not installed. Install with pip install rpy2 to run tools with R
# support.
# ryp2 is not installed. Install with pip install rpy2 to run tools with R
# support.
# ryp2 is not installed. Install with pip install rpy2 to run tools with R
# support.
# ryp2 is not installed. Install with pip install rpy2 to run tools with R
# support.
# ryp2 is not installed. Install with pip install rpy2 to run tools with R
# support.
# ryp2 is not installed. Install with pip install rpy2 to run tools with R
# support.
# ryp2 is not installed. Install with pip install rpy2 to run tools with R
# support.
# ryp2 is not installed. Install with pip install rpy2 to run tools with R
# support.
# ryp2 is not installed. Install with pip install rpy2 to run tools with R
# support.
# ryp2 is not installed. Install with pip install rpy2 to run tools with R
# support.
# ryp2 is not installed. Install with pip install rpy2 to run tools with R
# support.
# ryp2 is not installed. Install with pip install rpy2 to run tools with R
# support.
# ryp2 is not installed. Install with pip install rpy2 to run tools with R
# support.
# ryp2 is not installed. Install with pip install rpy2 to run tools with R
# support.
# ryp2 is not installed. Install with pip install rpy2 to run tools with R
# support.
# ryp2 is not installed. Install with pip install rpy2 to run tools with R
# support.
# ryp2 is not installed. Install with pip install rpy2 to run tools with R
# support.
# ryp2 is not installed. Install with pip install rpy2 to run tools with R
# support.
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# ...
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#                   ectopic EC  Aberrant Basaloid  Pericytes  Myofibroblasts
# mean_augur_score    0.617063           0.709161   0.650975        0.656247
# mean_auc            0.617063           0.709161   0.650975        0.656247
# mean_accuracy       0.577564           0.658755   0.598901        0.598205
# mean_precision      0.611466           0.676281   0.637784        0.624850
# mean_f1             0.534457           0.638792   0.541831        0.550572
# mean_recall         0.527302           0.648175   0.521825        0.543810

# %%
ag_rfc.plot_lollipop(nintedanib_results)
plt.xlim([0.5, 0.75])
plt.savefig("figures/nintedanib_augur_lollipop.png", bbox_inches="tight")

# %%
important_features = ag_rfc.plot_important_features(nintedanib_results, top_n=15)
plt.savefig("figures/nintedanib_augur_feature_importance.png", bbox_inches="tight")

# %%
loaded_data2.var["name"] = loaded_data2.var_names

# %%
cmp4_adata, cmp4_results = ag_rfc.predict(
    loaded_data2,
    n_subsamples=100,
    subsample_size=20,
    n_threads=32,
    select_variance_features=True,
)

cmp4_results["summary_metrics"]
# Out:
# Set smaller span value in the case of a `segmentation fault` error.
# Set larger span in case of svddc or other near singularities error.
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# ...
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/pertpy/pertpy/tools/_augur.py:238: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   subsample = AnnData.concatenate(*label_subsamples, index_unique=None)
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/icb/lukas.heumos/miniconda3/envs/pertpy/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(

# %%
ag_rfc.plot_lollipop(cmp4_results)
plt.xlim([0.5, 0.75])
plt.savefig("figures/cmp4_augur_lollipop.png", bbox_inches="tight")

# %%
important_features = ag_rfc.plot_important_features(cmp4_results, top_n=15)
plt.xticks(rotation=30)
plt.savefig("figures/cmp4_augur_feature_importance.png", bbox_inches="tight")

# %%
ag_rfc.plot_scatterplot(nintedanib_results, cmp4_results)

# %%
plt.savefig("figures/cmp4_vs_nintedanib_augur.png", bbox_inches="tight")

# %%
nintedanib_scores = nintedanib_results["summary_metrics"].loc["mean_augur_score",]
cmp4_scores = cmp4_results["summary_metrics"].loc["mean_augur_score",]

# %%
nintedanib_scores = pd.DataFrame(nintedanib_scores)
nintedanib_scores["treatment"] = "Nintedanib"
nintedanib_scores.reset_index(inplace=True)
nintedanib_scores.rename(columns={"index": "cell_type"}, inplace=True)
nintedanib_scores

# %%
cmp4_scores = pd.DataFrame(cmp4_scores)
cmp4_scores["treatment"] = "cmp4"
cmp4_scores.reset_index(inplace=True)
cmp4_scores.rename(columns={"index": "cell_type"}, inplace=True)
cmp4_scores

# %%
scores = pd.concat([cmp4_scores, nintedanib_scores], axis=0)
scores
