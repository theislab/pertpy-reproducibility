# %%
import warnings

warnings.filterwarnings("ignore")

# %%
from pathlib import Path
import sys

sys.path.insert(1, str(Path().cwd().parent))
import common_config

# %%
common_config.figure_journal_basic()

# %%
import pertpy as pt
import scanpy as sc
import matplotlib.pyplot as plt
import numpy as np

# %%
adata = pt.dt.norman_2019()

# %%
adata.obs
# Out:
#                                             guide_identity  read_count  \
# index
# AAACCTGAGAAGAAGC-1    NegCtrl0_NegCtrl0__NegCtrl0_NegCtrl0        1252
# AAACCTGAGGCATGTG-1      TSC22D1_NegCtrl0__TSC22D1_NegCtrl0        2151
# AAACCTGAGGCCCTTG-1                KLF1_MAP2K6__KLF1_MAP2K6        1037
# AAACCTGCACGAAGCA-1  NegCtrl10_NegCtrl0__NegCtrl10_NegCtrl0         958
# AAACCTGCAGACGTAG-1            CEBPE_RUNX1T1__CEBPE_RUNX1T1         244
# ...                                                    ...         ...
# TTTGTCATCAGTACGT-8          FOXA3_NegCtrl0__FOXA3_NegCtrl0        2068
# TTTGTCATCCACTCCA-8          CELF2_NegCtrl0__CELF2_NegCtrl0         829
# TTTGTCATCCCAACGG-8        BCORL1_NegCtrl0__BCORL1_NegCtrl0         136
# TTTGTCATCCTCCTAG-8            ZBTB10_PTPN12__ZBTB10_PTPN12        1254
# TTTGTCATCTGGCGAC-8        MAP4K3_NegCtrl0__MAP4K3_NegCtrl0        1226
#
#                     UMI_count   coverage  gemgroup  good_coverage  \
# index
# ...

# %%
adata.obs["perturbed"] = np.where(
    adata.obs["perturbation_name"] == "control", "control", "perturbed"
)

# %%
# Cell cycle genes identified by Tirosh et al., 2016
s_genes = [
    "MCM5",
    "PCNA",
    "TYMS",
    "FEN1",
    "MCM2",
    "MCM4",
    "RRM1",
    "UNG",
    "GINS2",
    "MCM6",
    "CDCA7",
    "DTL",
    "PRIM1",
    "UHRF1",
    "HELLS",
    "RFC2",
    "RPA2",
    "NASP",
    "RAD51AP1",
    "GMNN",
    "WDR76",
    "SLBP",
    "CCNE2",
    "UBR7",
    "POLD3",
    "MSH2",
    "ATAD2",
    "RAD51",
    "RRM2",
    "CDC45",
    "CDC6",
    "EXO1",
    "TIPIN",
    "DSCC1",
    "BLM",
    "CASP8AP2",
    "USP1",
    "CLSPN",
    "POLA1",
    "CHAF1B",
    "BRIP1",
    "E2F8",
]

g2m_genes = [
    "HMGB2",
    "CDK1",
    "NUSAP1",
    "UBE2C",
    "BIRC5",
    "TPX2",
    "TOP2A",
    "NDC80",
    "CKS2",
    "NUF2",
    "CKS1B",
    "MKI67",
    "TMPO",
    "CENPF",
    "TACC3",
    "FAM64A",
    "SMC4",
    "CCNB2",
    "CKAP2L",
    "CKAP2",
    "AURKB",
    "BUB1",
    "KIF11",
    "ANP32E",
    "TUBB4B",
    "GTSE1",
    "KIF20B",
    "HJURP",
    "CDCA3",
    "HN1",
    "CDC20",
    "TTK",
    "CDC25C",
    "KIF2C",
    "RANGAP1",
    "NCAPD2",
    "DLGAP5",
    "CDCA2",
    "CDCA8",
    "ECT2",
    "KIF23",
    "HMMR",
    "AURKA",
    "PSRC1",
    "ANLN",
    "LBR",
    "CKAP5",
    "CENPE",
    "CTCF",
    "NEK2",
    "G2E3",
    "GAS2L3",
    "CBX5",
    "CENPA",
]

sc.tl.score_genes_cell_cycle(adata, s_genes=s_genes, g2m_genes=g2m_genes)

# %%
sc.pp.normalize_total(adata)
sc.pp.log1p(adata)
sc.pp.highly_variable_genes(adata, subset=True, n_top_genes=4000)

# %%
sc.pp.neighbors(adata)

# %%
sc.pp.pca(adata)

# %%
sc.tl.umap(adata)

# %%
sc.pl.umap(adata, color="perturbation_name")

# %%
sc.pl.umap(adata, color="phase", palette="Set3", show=False)
plt.savefig("figures/phase_umap.png", bbox_inches="tight")

# %%
sc.write("data/norman_preprocessed.h5ad", adata)
